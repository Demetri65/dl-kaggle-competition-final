# %% [markdown]
# # Stage 3 Balanced Answer Index Training (A100)
#
# Thin Colab orchestration notebook for training `c03_balanced_answer`, the f04 formulation with answer-index-balanced sampling.

# %% [markdown]
# ## 1. Mount Google Drive
#
# Mount Google Drive before running the repo bootstrap flow.

# %%
from google.colab import drive

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 2. Configure Paths
#
# Set the repo checkout path, Drive output directory, experiment ID, smoke size, and optional data override.

# %%
from pathlib import Path

REPO_URL = "https://github.com/Demetri65/dl-kaggle-competition-final.git"
REPO_REF = "main"
REPO_DIR = Path("/content/dl-kaggle-competition-final")
SOURCE_ENV = Path("/content/.env")
UPLOADER_KEY = "_env_uploader"
DRIVE_OUTPUT_DIR = "/content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100"
DATA_DIR_OVERRIDE = ""
EXPERIMENT_ID = "c03_balanced_answer"
SMOKE_TRAIN_EXAMPLES = 128
SMOKE_VAL_EXAMPLES = 128
EVAL_BATCH_SIZE = 16
INFERENCE_COMPLETION_BATCH_SIZE = 16

# %% [markdown]
# ## 3. Prepare The Repo
#
# Upload `.env` if needed, sync the repo, and run `scripts/bootstrap_colab.sh`.

# %%
# -- 0. Colab setup ------------------------------------------------
import subprocess
import ipywidgets as widgets
from IPython.display import display


def get_uploaded_file(uploader):
    value = uploader.value

    if isinstance(value, dict):
        filename, uploaded_file = next(iter(value.items()))
        if isinstance(uploaded_file, dict):
            content = uploaded_file.get("content", uploaded_file.get("data"))
        else:
            content = uploaded_file
    else:
        uploaded_file = value[0]
        if isinstance(uploaded_file, dict):
            filename = uploaded_file["name"]
            content = uploaded_file["content"]
        else:
            filename = uploaded_file.name
            content = uploaded_file.content

    payload = content.tobytes() if hasattr(content, "tobytes") else bytes(content)
    return filename, payload


ready_to_bootstrap = SOURCE_ENV.exists()

if ready_to_bootstrap:
    print(f"Using existing {SOURCE_ENV}")
else:
    uploader = globals().get(UPLOADER_KEY)
    if uploader is None:
        uploader = widgets.FileUpload(accept=".env", multiple=False, description="Upload .env")
        globals()[UPLOADER_KEY] = uploader

    if not uploader.value:
        display(uploader)
        print("Select your local .env file in the upload widget above, then rerun this cell.")
    else:
        filename, payload = get_uploaded_file(uploader)
        SOURCE_ENV.write_bytes(payload)
        SOURCE_ENV.chmod(0o600)
        print(f"Saved {filename} to {SOURCE_ENV}")
        uploader.close()
        globals().pop(UPLOADER_KEY, None)
        ready_to_bootstrap = True

if ready_to_bootstrap:
    if not REPO_DIR.exists():
        subprocess.run(["git", "clone", "--depth", "1", "--branch", REPO_REF, REPO_URL, str(REPO_DIR)], check=True)
    else:
        subprocess.run(["git", "-C", str(REPO_DIR), "fetch", "--depth", "1", "origin", REPO_REF], check=True)
        subprocess.run(["git", "-C", str(REPO_DIR), "reset", "--hard", "FETCH_HEAD"], check=True)

    print(f"Repo synced to latest origin/{REPO_REF} at {REPO_DIR}")
    result = subprocess.run(
        ["bash", "scripts/bootstrap_colab.sh"],
        cwd=REPO_DIR,
        capture_output=True,
        text=True,
    )
    if result.stdout:
        print(result.stdout, end="")
    if result.returncode != 0:
        if result.stderr:
            print(result.stderr, end="")
        raise RuntimeError(f"scripts/bootstrap_colab.sh failed with exit code {result.returncode}")
# Out:
# Saved .env to /content/.env
# Repo synced to latest origin/main at /content/dl-kaggle-competition-final
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.1-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 84.3 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-26.1
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (1.13.0)
# Collecting bitsandbytes (from -r requirements.txt (line 2))
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (4.0.0)
# Requirement already satisfied: kaggle==2.0.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (2.2.2)
# Requirement already satisfied: peft==0.18.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (0.18.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (11.3.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (6.0.3)
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (8.4.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (2.10.0+cu128)
# Collecting transformers==4.57.6 (from -r requirements.txt (line 12))
#   Downloading transformers-4.57.6-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle==2.0.1->-r requirements.txt (line 4)) (6.3.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from kaggle==2.0.1->-r requirements.txt (line 4)) (0.1.18)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaggle==2.0.1->-r requirements.txt (line 4)) (26.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle==2.0.1->-r requirements.txt (line 4)) (5.29.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from kaggle==2.0.1->-r requirements.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle==2.0.1->-r requirements.txt (line 4)) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle==2.0.1->-r requirements.txt (line 4)) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle==2.0.1->-r requirements.txt (line 4)) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle==2.0.1->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft==0.18.1->-r requirements.txt (line 7)) (5.9.5)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft==0.18.1->-r requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.18.1->-r requirements.txt (line 7)) (1.10.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6->-r requirements.txt (line 12)) (3.25.2)
# Collecting huggingface_hub>=0.25.0 (from peft==0.18.1->-r requirements.txt (line 7))
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6->-r requirements.txt (line 12)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.57.6->-r requirements.txt (line 12)) (0.22.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.18.1->-r requirements.txt (line 7)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.18.1->-r requirements.txt (line 7)) (1.4.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft==0.18.1->-r requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 11)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch->-r requirements.txt (line 11)) (1.5.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 3)) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 3)) (0.3.8)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 3)) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 3)) (3.13.5)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 6)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 6)) (2026.1)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest->-r requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest->-r requirements.txt (line 10)) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest->-r requirements.txt (line 10)) (2.20.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 3)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 3)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 3)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 3)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 3)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 3)) (1.23.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 3)) (3.11)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->kaggle==2.0.1->-r requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle==2.0.1->-r requirements.txt (line 4)) (3.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle==2.0.1->-r requirements.txt (line 4)) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 11)) (1.3.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->kaggle==2.0.1->-r requirements.txt (line 4)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 11)) (3.0.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify->kaggle==2.0.1->-r requirements.txt (line 4)) (1.3)
# Downloading transformers-4.57.6-py3-none-any.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 179.2 MB/s  0:00:00
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 32.5 MB/s  0:00:00
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 180.7 MB/s  0:00:00
# Installing collected packages: huggingface_hub, transformers, bitsandbytes
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.10.1
#     Uninstalling huggingface_hub-1.10.1:
#       Successfully uninstalled huggingface_hub-1.10.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
#
# Successfully installed bitsandbytes-0.49.2 huggingface_hub-0.36.2 transformers-4.57.6
# Using Kaggle CLI Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.1), please consider upgrading to the latest version (2.0.2)
# Kaggle CLI 2.0.1
# Warning: Looks like you're using an outdated `kaggle` version (installed: 2.0.1), please consider upgrading to the latest version (2.0.2)
# Downloading pixels-to-predictions.zip to /content/dl-kaggle-competition-final/data
#
# Extracting pixels-to-predictions.zip
# Competition files downloaded to: /content/dl-kaggle-competition-final/data

# %% [markdown]
# ## 4. Helpers
#
# Helpers route every run through the repo scripts and print the resolved config for verification.

# %%
import os
import shlex
import subprocess
from pathlib import Path

import yaml

REPO_ROOT = REPO_DIR.resolve()
Path(DRIVE_OUTPUT_DIR).mkdir(parents=True, exist_ok=True)
os.chdir(REPO_ROOT)

COMMON_OVERRIDES = []
if DATA_DIR_OVERRIDE:
    COMMON_OVERRIDES.append(f"data.data_dir={DATA_DIR_OVERRIDE}")


def with_common_overrides(overrides):
    return [*COMMON_OVERRIDES, *overrides]


def extend_with_overrides(args, overrides):
    for override in overrides:
        args.extend(["--set", override])


def run_repo_command(args):
    command = ["python3", *args]
    print("$", " ".join(shlex.quote(part) for part in command))
    result = subprocess.run(command, cwd=REPO_ROOT, capture_output=True, text=True)
    if result.stdout:
        print(result.stdout, end="")
    if result.stderr:
        print(result.stderr, end="")
    if result.returncode != 0:
        raise RuntimeError(f"Command failed with exit code {result.returncode}")
    return result


def find_resolved_config(run_root: Path, experiment_id: str) -> Path:
    candidates = sorted(run_root.glob(f"{experiment_id}_seed*/resolved_config.yaml"))
    if not candidates:
        raise FileNotFoundError(f"No resolved_config.yaml found under {run_root}")
    if len(candidates) > 1:
        print(f"Multiple resolved configs found; using {candidates[-1]}")
    return candidates[-1]


def verify_resolved_config(run_root: Path):
    path = find_resolved_config(run_root, EXPERIMENT_ID)
    config = yaml.safe_load(path.read_text())
    fields = [name for name, enabled in config["fields"].items() if enabled]
    print(f"Resolved config: {path}")
    print(f"experiment_id: {config['experiment_id']}")
    print(f"parent_experiment_id: {config.get('parent_experiment_id')}")
    print(f"formulation.mode: {config['formulation']['mode']}")
    print(f"prompting.template: {config['prompting']['template']}")
    print(f"sampling.mode: {config['sampling']['mode']}")
    print(f"training.epochs: {config['training']['epochs']}")
    print(f"training.bf16: {config['training']['bf16']}")
    print(f"training.fp16: {config['training']['fp16']}")
    print(f"training.eval_batch_size: {config['training']['eval_batch_size']}")
    print(f"scoring.max_completion_batch_size: {config['scoring']['max_completion_batch_size']}")
    print(f"fields: {fields}")


print(f"Repo root: {REPO_ROOT}")
print(f"Drive output dir: {DRIVE_OUTPUT_DIR}")
print(f"Experiment: {EXPERIMENT_ID}")
if DATA_DIR_OVERRIDE:
    print(f"Data override: {DATA_DIR_OVERRIDE}")
# Out:
# Repo root: /content/dl-kaggle-competition-final
# Drive output dir: /content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100
# Experiment: c03_balanced_answer

# %% [markdown]
# ## 5. Smoke Train/Eval
#
# Train a 128-example smoke run for `balanced answer index` before spending a full A100 run.

# %%
smoke_root = Path(DRIVE_OUTPUT_DIR) / "smoke"
smoke_args = [
    "scripts/run_experiment.py",
    "--experiment", EXPERIMENT_ID,
    "--output-dir", str(smoke_root),
]
extend_with_overrides(smoke_args, with_common_overrides([
    "training.epochs=1",
    "training.bf16=true",
    "training.fp16=false",
    f"training.eval_batch_size={EVAL_BATCH_SIZE}",
    f"scoring.max_completion_batch_size={INFERENCE_COMPLETION_BATCH_SIZE}",
    f"runtime.max_train_examples={SMOKE_TRAIN_EXAMPLES}",
    f"runtime.max_val_examples={SMOKE_VAL_EXAMPLES}",
]))
run_repo_command(smoke_args)
verify_resolved_config(smoke_root)
# Out:
# $ python3 scripts/run_experiment.py --experiment c03_balanced_answer --output-dir /content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100/smoke --set training.epochs=1 --set training.bf16=true --set training.fp16=false --set training.eval_batch_size=16 --set scoring.max_completion_batch_size=16 --set runtime.max_train_examples=128 --set runtime.max_val_examples=128
# LoRA target patterns: ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'out_proj']
# Matched LoRA modules:
#   - model.text_model.layers.0.self_attn.k_proj
#   - model.text_model.layers.0.self_attn.o_proj
#   - model.text_model.layers.0.self_attn.q_proj
#   - model.text_model.layers.0.self_attn.v_proj
#   - model.text_model.layers.1.self_attn.k_proj
#   - model.text_model.layers.1.self_attn.o_proj
#   - model.text_model.layers.1.self_attn.q_proj
#   - model.text_model.layers.1.self_attn.v_proj
#   - model.text_model.layers.10.self_attn.k_proj
#   - model.text_model.layers.10.self_attn.o_proj
#   - model.text_model.layers.10.self_attn.q_proj
#   - model.text_model.layers.10.self_attn.v_proj
#   - model.text_model.layers.11.self_attn.k_proj
#   - model.text_model.layers.11.self_attn.o_proj
#   - model.text_model.layers.11.self_attn.q_proj
#   - model.text_model.layers.11.self_attn.v_proj
#   - model.text_model.layers.12.self_attn.k_proj
#   - model.text_model.layers.12.self_attn.o_proj
#   - model.text_model.layers.12.self_attn.q_proj
#   - model.text_model.layers.12.self_attn.v_proj
#   - model.text_model.layers.13.self_attn.k_proj
#   - model.text_model.layers.13.self_attn.o_proj
#   - model.text_model.layers.13.self_attn.q_proj
#   - model.text_model.layers.13.self_attn.v_proj
#   - model.text_model.layers.14.self_attn.k_proj
#   - model.text_model.layers.14.self_attn.o_proj
#   - model.text_model.layers.14.self_attn.q_proj
#   - model.text_model.layers.14.self_attn.v_proj
#   - model.text_model.layers.15.self_attn.k_proj
#   - model.text_model.layers.15.self_attn.o_proj
#   - model.text_model.layers.15.self_attn.q_proj
#   - model.text_model.layers.15.self_attn.v_proj
#   - model.text_model.layers.16.self_attn.k_proj
#   - model.text_model.layers.16.self_attn.o_proj
#   - model.text_model.layers.16.self_attn.q_proj
#   - model.text_model.layers.16.self_attn.v_proj
#   - model.text_model.layers.17.self_attn.k_proj
#   - model.text_model.layers.17.self_attn.o_proj
#   - model.text_model.layers.17.self_attn.q_proj
#   - model.text_model.layers.17.self_attn.v_proj
#   - model.text_model.layers.18.self_attn.k_proj
#   - model.text_model.layers.18.self_attn.o_proj
#   - model.text_model.layers.18.self_attn.q_proj
#   - model.text_model.layers.18.self_attn.v_proj
#   - model.text_model.layers.19.self_attn.k_proj
#   - model.text_model.layers.19.self_attn.o_proj
#   - model.text_model.layers.19.self_attn.q_proj
#   - model.text_model.layers.19.self_attn.v_proj
#   - model.text_model.layers.2.self_attn.k_proj
#   - model.text_model.layers.2.self_attn.o_proj
#   - model.text_model.layers.2.self_attn.q_proj
#   - model.text_model.layers.2.self_attn.v_proj
#   - model.text_model.layers.20.self_attn.k_proj
#   - model.text_model.layers.7.self_attn.o_proj
#   - model.text_model.layers.7.self_attn.q_proj
#   - model.text_model.layers.7.self_attn.v_proj
#   - model.text_model.layers.8.self_attn.k_proj
#   - model.text_model.layers.8.self_attn.o_proj
#   - model.text_model.layers.8.self_attn.q_proj
#   - model.text_model.layers.8.self_attn.v_proj
#   - model.text_model.layers.9.self_attn.k_proj
#   - model.text_model.layers.9.self_attn.o_proj
#   - model.text_model.layers.9.self_attn.q_proj
#   - model.text_model.layers.9.self_attn.v_proj
#   - model.vision_model.encoder.layers.0.self_attn.k_proj
#   - model.vision_model.encoder.layers.0.self_attn.out_proj
#   - model.vision_model.encoder.layers.0.self_attn.q_proj
#   - model.vision_model.encoder.layers.0.self_attn.v_proj
#   - model.vision_model.encoder.layers.1.self_attn.k_proj
#   - model.vision_model.encoder.layers.1.self_attn.out_proj
#   - model.vision_model.encoder.layers.1.self_attn.q_proj
#   - model.vision_model.encoder.layers.1.self_attn.v_proj
#   - model.vision_model.encoder.layers.10.self_attn.k_proj
#   - model.vision_model.encoder.layers.10.self_attn.out_proj
#   - model.vision_model.encoder.layers.10.self_attn.q_proj
#   - model.vision_model.encoder.layers.10.self_attn.v_proj
#   - model.vision_model.encoder.layers.11.self_attn.k_proj
#   - model.vision_model.encoder.layers.11.self_attn.out_proj
#   - model.vision_model.encoder.layers.11.self_attn.q_proj
#   - model.vision_model.encoder.layers.11.self_attn.v_proj
#   - model.vision_model.encoder.layers.2.self_attn.k_proj
#   - model.vision_model.encoder.layers.2.self_attn.out_proj
#   - model.vision_model.encoder.layers.2.self_attn.q_proj
#   - model.vision_model.encoder.layers.2.self_attn.v_proj
#   - model.vision_model.encoder.layers.3.self_attn.k_proj
#   - model.vision_model.encoder.layers.3.self_attn.out_proj
#   - model.vision_model.encoder.layers.3.self_attn.q_proj
#   - model.vision_model.encoder.layers.3.self_attn.v_proj
#   - model.vision_model.encoder.layers.4.self_attn.k_proj
#   - model.vision_model.encoder.layers.4.self_attn.out_proj
#   - model.vision_model.encoder.layers.4.self_attn.q_proj
#   - model.vision_model.encoder.layers.4.self_attn.v_proj
#   - model.vision_model.encoder.layers.5.self_attn.k_proj
#   - model.vision_model.encoder.layers.5.self_attn.out_proj
#   - model.vision_model.encoder.layers.5.self_attn.q_proj
#   - model.vision_model.encoder.layers.5.self_attn.v_proj
#   - model.vision_model.encoder.layers.6.self_attn.k_proj
#   - model.vision_model.encoder.layers.6.self_attn.out_proj
#   - model.vision_model.encoder.layers.6.self_attn.q_proj
#   - model.vision_model.encoder.layers.6.self_attn.v_proj
#   - model.vision_model.encoder.layers.7.self_attn.k_proj
#   - model.vision_model.encoder.layers.7.self_attn.out_proj
#   - model.vision_model.encoder.layers.7.self_attn.q_proj
#   - model.vision_model.encoder.layers.7.self_attn.v_proj
#   - model.vision_model.encoder.layers.8.self_attn.k_proj
#   - model.vision_model.encoder.layers.8.self_attn.out_proj
#   - model.vision_model.encoder.layers.8.self_attn.q_proj
#   - model.vision_model.encoder.layers.8.self_attn.v_proj
#   - model.vision_model.encoder.layers.9.self_attn.k_proj
#   - model.vision_model.encoder.layers.9.self_attn.out_proj
#   - model.vision_model.encoder.layers.9.self_attn.q_proj
#   - model.vision_model.encoder.layers.9.self_attn.v_proj
# Trainable parameter count: 4456448
# epoch=1 step=10 loss=2.4155
# epoch=1 step=20 loss=0.9522
# epoch=1 step=30 loss=0.6000
# epoch=1 step=40 loss=0.5790
# epoch=1 step=50 loss=0.6249
# epoch=1 step=60 loss=0.6137
# epoch=1 step=70 loss=0.4693
# epoch=1 step=80 loss=0.6673
# epoch=1 step=90 loss=0.5768
# epoch=1 step=100 loss=0.5311
# epoch=1 step=110 loss=0.4145
# epoch=1 step=120 loss=0.4848
# epoch=1 step=130 loss=0.5877
# val: evaluating 128 items in 8 batches
# val: batch 1/8 items 16/128 elapsed 150.6s
# val: batch 8/8 items 128/128 elapsed 924.7s
# {
#   "adapter_enabled": true,
#   "eval_artifact_dir": null,
#   "experiment_id": "c03_balanced_answer",
#   "matched_lora_modules": [
#     "model.text_model.layers.0.self_attn.k_proj",
#     "model.text_model.layers.0.self_attn.o_proj",
#     "model.text_model.layers.0.self_attn.q_proj",
#     "model.text_model.layers.0.self_attn.v_proj",
#     "model.text_model.layers.1.self_attn.k_proj",
#     "model.text_model.layers.1.self_attn.o_proj",
#     "model.text_model.layers.1.self_attn.q_proj",
#     "model.text_model.layers.1.self_attn.v_proj",
#     "model.text_model.layers.10.self_attn.k_proj",
#     "model.text_model.layers.10.self_attn.o_proj",
#     "model.text_model.layers.10.self_attn.q_proj",
#     "model.text_model.layers.10.self_attn.v_proj",
#     "model.text_model.layers.11.self_attn.k_proj",
#     "model.text_model.layers.11.self_attn.o_proj",
#     "model.text_model.layers.11.self_attn.q_proj",
#     "model.text_model.layers.11.self_attn.v_proj",
#     "model.text_model.layers.12.self_attn.k_proj",
#     "model.text_model.layers.12.self_attn.o_proj",
#     "model.text_model.layers.12.self_attn.q_proj",
#     "model.text_model.layers.12.self_attn.v_proj",
#     "model.text_model.layers.13.self_attn.k_proj",
#     "model.text_model.layers.13.self_attn.o_proj",
#     "model.text_model.layers.13.self_attn.q_proj",
#     "model.text_model.layers.13.self_attn.v_proj",
#     "model.text_model.layers.14.self_attn.k_proj",
#     "model.text_model.layers.14.self_attn.o_proj",
#     "model.text_model.layers.14.self_attn.q_proj",
#     "model.text_model.layers.14.self_attn.v_proj",
#     "model.text_model.layers.15.self_attn.k_proj",
#     "model.text_model.layers.15.self_attn.o_proj",
#     "model.text_model.layers.15.self_attn.q_proj",
#     "model.text_model.layers.15.self_attn.v_proj",
#     "model.text_model.layers.16.self_attn.k_proj",
#     "model.text_model.layers.16.self_attn.o_proj",
#     "model.text_model.layers.16.self_attn.q_proj",
#     "model.text_model.layers.16.self_attn.v_proj",
#     "model.text_model.layers.17.self_attn.k_proj",
#     "model.text_model.layers.17.self_attn.o_proj",
#     "model.text_model.layers.17.self_attn.q_proj",
#     "model.text_model.layers.17.self_attn.v_proj",
#     "model.text_model.layers.18.self_attn.k_proj",
#     "model.text_model.layers.31.self_attn.q_proj",
#     "model.text_model.layers.31.self_attn.v_proj",
#     "model.text_model.layers.4.self_attn.k_proj",
#     "model.text_model.layers.4.self_attn.o_proj",
#     "model.text_model.layers.4.self_attn.q_proj",
#     "model.text_model.layers.4.self_attn.v_proj",
#     "model.text_model.layers.5.self_attn.k_proj",
#     "model.text_model.layers.5.self_attn.o_proj",
#     "model.text_model.layers.5.self_attn.q_proj",
#     "model.text_model.layers.5.self_attn.v_proj",
#     "model.text_model.layers.6.self_attn.k_proj",
#     "model.text_model.layers.6.self_attn.o_proj",
#     "model.text_model.layers.6.self_attn.q_proj",
#     "model.text_model.layers.6.self_attn.v_proj",
#     "model.text_model.layers.7.self_attn.k_proj",
#     "model.text_model.layers.7.self_attn.o_proj",
#     "model.text_model.layers.7.self_attn.q_proj",
#     "model.text_model.layers.7.self_attn.v_proj",
#     "model.text_model.layers.8.self_attn.k_proj",
#     "model.text_model.layers.8.self_attn.o_proj",
#     "model.text_model.layers.8.self_attn.q_proj",
#     "model.text_model.layers.8.self_attn.v_proj",
#     "model.text_model.layers.9.self_attn.k_proj",
#     "model.text_model.layers.9.self_attn.o_proj",
#     "model.text_model.layers.9.self_attn.q_proj",
#     "model.text_model.layers.9.self_attn.v_proj",
#     "model.vision_model.encoder.layers.0.self_attn.k_proj",
#     "model.vision_model.encoder.layers.0.self_attn.out_proj",
#     "model.vision_model.encoder.layers.0.self_attn.q_proj",
#     "model.vision_model.encoder.layers.0.self_attn.v_proj",
#     "model.vision_model.encoder.layers.1.self_attn.k_proj",
#     "model.vision_model.encoder.layers.1.self_attn.out_proj",
#     "model.vision_model.encoder.layers.1.self_attn.q_proj",
#     "model.vision_model.encoder.layers.1.self_attn.v_proj",
#     "model.vision_model.encoder.layers.10.self_attn.k_proj",
#     "model.vision_model.encoder.layers.10.self_attn.out_proj",
#     "model.vision_model.encoder.layers.10.self_attn.q_proj",
#     "model.vision_model.encoder.layers.10.self_attn.v_proj",
#     "model.vision_model.encoder.layers.11.self_attn.k_proj",
#     "model.vision_model.encoder.layers.11.self_attn.out_proj",
#     "model.vision_model.encoder.layers.11.self_attn.q_proj",
#     "model.vision_model.encoder.layers.11.self_attn.v_proj",
#     "model.vision_model.encoder.layers.2.self_attn.k_proj",
#     "model.vision_model.encoder.layers.2.self_attn.out_proj",
#     "model.vision_model.encoder.layers.2.self_attn.q_proj",
#     "model.vision_model.encoder.layers.2.self_attn.v_proj",
#     "model.vision_model.encoder.layers.3.self_attn.k_proj",
#     "model.vision_model.encoder.layers.3.self_attn.out_proj",
#     "model.vision_model.encoder.layers.3.self_attn.q_proj",
#     "model.vision_model.encoder.layers.3.self_attn.v_proj",
#     "model.vision_model.encoder.layers.4.self_attn.k_proj",
#     "model.vision_model.encoder.layers.4.self_attn.out_proj",
#     "model.vision_model.encoder.layers.4.self_attn.q_proj",
#     "model.vision_model.encoder.layers.4.self_attn.v_proj",
#     "model.vision_model.encoder.layers.5.self_attn.k_proj",
#     "model.vision_model.encoder.layers.5.self_attn.out_proj",
#     "model.vision_model.encoder.layers.5.self_attn.q_proj",
#     "model.vision_model.encoder.layers.5.self_attn.v_proj",
#     "model.vision_model.encoder.layers.6.self_attn.k_proj",
#     "model.vision_model.encoder.layers.6.self_attn.out_proj",
#     "model.vision_model.encoder.layers.6.self_attn.q_proj",
#     "model.vision_model.encoder.layers.6.self_attn.v_proj",
#     "model.vision_model.encoder.layers.7.self_attn.k_proj",
#     "model.vision_model.encoder.layers.7.self_attn.out_proj",
#     "model.vision_model.encoder.layers.7.self_attn.q_proj",
#     "model.vision_model.encoder.layers.7.self_attn.v_proj",
#     "model.vision_model.encoder.layers.8.self_attn.k_proj",
#     "model.vision_model.encoder.layers.8.self_attn.out_proj",
#     "model.vision_model.encoder.layers.8.self_attn.q_proj",
#     "model.vision_model.encoder.layers.8.self_attn.v_proj",
#     "model.vision_model.encoder.layers.9.self_attn.k_proj",
#     "model.vision_model.encoder.layers.9.self_attn.out_proj",
#     "model.vision_model.encoder.layers.9.self_attn.q_proj",
#     "model.vision_model.encoder.layers.9.self_attn.v_proj"
#   ],
#   "output_dir": "/content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100/smoke/c03_balanced_answer_seed42",
#   "resolved_config_path": "/content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100/smoke/c03_balanced_answer_seed42/resolved_config.yaml",
#   "run_mode": "train_eval",
#   "run_name": "c03_balanced_answer_seed42",
#   "run_summary_path": "/content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100/smoke/c03_balanced_answer_seed42/run_summary.yaml",
#   "submission_path": null,
#   "target_lora_modules": [
#     "q_proj",
#     "k_proj",
#     "v_proj",
#     "o_proj",
#     "out_proj"
#   ],
#   "test_predictions_path": null,
#   "trainable_parameters": 4456448,
#   "unmatched_lora_targets": [],
#   "val_metrics": {
#     "accuracy_by_num_choices": {
#       "2": 0.5,
#       "3": 0.5555555555555556,
#       "4": 0.23529411764705882,
#       "5": 0.3023255813953488
#     },
#     "accuracy_by_subject": {
#       "language science": 0.0,
#       "natural science": 0.42857142857142855,
#       "social science": 0.3333333333333333
#     },
#     "accuracy_by_task": {
#       "closed choice": 0.4140625
#     },
#     "overall_accuracy": 0.4140625,
#     "prediction_distribution": {
#       "0": 0.2734375,
#       "1": 0.390625,
#       "2": 0.171875,
#       "3": 0.09375,
#       "4": 0.0703125
#     },
#     "two_choice_accuracy": 0.5,
#     "two_choice_support": 32,
#     "yes_no_true_false_accuracy": null,
#     "yes_no_true_false_support": 0
#   },
#   "val_predictions_path": "/content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100/smoke/c03_balanced_answer_seed42/artifacts/val_predictions.jsonl"
# }
# 2026-04-27 02:20:06.466400: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-27 02:20:06.484989: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777256406.507516    4286 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777256406.515077    4286 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777256406.534314    4286 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777256406.534346    4286 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777256406.534349    4286 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777256406.534351    4286 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-27 02:20:06.539273: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# `torch_dtype` is deprecated! Use `dtype` instead!
# /content/dl-kaggle-competition-final/src/training/train.py:211: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=torch.cuda.is_available() and config.training.fp16)
# /usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:232: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   check_backward_validity(args)
# Resolved config: /content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100/smoke/c03_balanced_answer_seed42/resolved_config.yaml
# experiment_id: c03_balanced_answer
# parent_experiment_id: f04_candidate_yes_no
# formulation.mode: candidate_yes_no
# prompting.template: candidate_yes_no
# sampling.mode: balanced_answer_index
# training.epochs: 1
# training.bf16: True
# training.fp16: False
# training.eval_batch_size: 16
# scoring.max_completion_batch_size: 16
# fields: ['image', 'question']

# %% [markdown]
# ## 6. Full Train/Eval
#
# Train on the train split and evaluate on validation. This is the model-selection run.

# %%
full_root = Path(DRIVE_OUTPUT_DIR) / "full"
full_args = [
    "scripts/run_experiment.py",
    "--experiment", EXPERIMENT_ID,
    "--output-dir", str(full_root),
]
extend_with_overrides(full_args, with_common_overrides([
    "training.epochs=1",
    "training.bf16=true",
    "training.fp16=false",
    f"training.eval_batch_size={EVAL_BATCH_SIZE}",
    f"scoring.max_completion_batch_size={INFERENCE_COMPLETION_BATCH_SIZE}",
]))
run_repo_command(full_args)
verify_resolved_config(full_root)
# Out:
# $ python3 scripts/run_experiment.py --experiment c03_balanced_answer --output-dir /content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100/full --set training.epochs=1 --set training.bf16=true --set training.fp16=false --set training.eval_batch_size=16 --set scoring.max_completion_batch_size=16
# LoRA target patterns: ['q_proj', 'k_proj', 'v_proj', 'o_proj', 'out_proj']
# Matched LoRA modules:
#   - model.text_model.layers.0.self_attn.k_proj
#   - model.text_model.layers.0.self_attn.o_proj
#   - model.text_model.layers.0.self_attn.q_proj
#   - model.text_model.layers.0.self_attn.v_proj
#   - model.text_model.layers.1.self_attn.k_proj
#   - model.text_model.layers.1.self_attn.o_proj
#   - model.text_model.layers.1.self_attn.q_proj
#   - model.text_model.layers.1.self_attn.v_proj
#   - model.text_model.layers.10.self_attn.k_proj
#   - model.text_model.layers.10.self_attn.o_proj
#   - model.text_model.layers.10.self_attn.q_proj
#   - model.text_model.layers.10.self_attn.v_proj
#   - model.text_model.layers.11.self_attn.k_proj
#   - model.text_model.layers.11.self_attn.o_proj
#   - model.text_model.layers.11.self_attn.q_proj
#   - model.text_model.layers.11.self_attn.v_proj
#   - model.text_model.layers.12.self_attn.k_proj
#   - model.text_model.layers.12.self_attn.o_proj
#   - model.text_model.layers.12.self_attn.q_proj
#   - model.text_model.layers.12.self_attn.v_proj
#   - model.text_model.layers.13.self_attn.k_proj
#   - model.text_model.layers.13.self_attn.o_proj
#   - model.text_model.layers.13.self_attn.q_proj
#   - model.text_model.layers.13.self_attn.v_proj
#   - model.text_model.layers.14.self_attn.k_proj
#   - model.text_model.layers.14.self_attn.o_proj
#   - model.text_model.layers.14.self_attn.q_proj
#   - model.text_model.layers.14.self_attn.v_proj
#   - model.text_model.layers.15.self_attn.k_proj
#   - model.text_model.layers.15.self_attn.o_proj
#   - model.vision_model.encoder.layers.4.self_attn.out_proj
#   - model.vision_model.encoder.layers.4.self_attn.q_proj
#   - model.vision_model.encoder.layers.4.self_attn.v_proj
#   - model.vision_model.encoder.layers.5.self_attn.k_proj
#   - model.vision_model.encoder.layers.5.self_attn.out_proj
#   - model.vision_model.encoder.layers.5.self_attn.q_proj
#   - model.vision_model.encoder.layers.5.self_attn.v_proj
#   - model.vision_model.encoder.layers.6.self_attn.k_proj
#   - model.vision_model.encoder.layers.6.self_attn.out_proj
#   - model.vision_model.encoder.layers.6.self_attn.q_proj
#   - model.vision_model.encoder.layers.6.self_attn.v_proj
#   - model.vision_model.encoder.layers.7.self_attn.k_proj
#   - model.vision_model.encoder.layers.7.self_attn.out_proj
#   - model.vision_model.encoder.layers.7.self_attn.q_proj
#   - model.vision_model.encoder.layers.7.self_attn.v_proj
#   - model.vision_model.encoder.layers.8.self_attn.k_proj
#   - model.vision_model.encoder.layers.8.self_attn.out_proj
#   - model.vision_model.encoder.layers.8.self_attn.q_proj
#   - model.vision_model.encoder.layers.8.self_attn.v_proj
#   - model.vision_model.encoder.layers.9.self_attn.k_proj
#   - model.vision_model.encoder.layers.9.self_attn.out_proj
#   - model.vision_model.encoder.layers.9.self_attn.q_proj
#   - model.vision_model.encoder.layers.9.self_attn.v_proj
# Trainable parameter count: 4456448
# epoch=1 step=10 loss=1.8868
# epoch=1 step=20 loss=2.1705
# epoch=1 step=30 loss=2.3130
# epoch=1 step=40 loss=1.7113
# epoch=1 step=50 loss=1.3774
# epoch=1 step=60 loss=0.6855
# epoch=1 step=70 loss=1.1579
# epoch=1 step=80 loss=1.0426
# epoch=1 step=90 loss=0.6088
# epoch=1 step=100 loss=0.6103
# epoch=1 step=110 loss=0.5437
# epoch=1 step=120 loss=0.3885
# epoch=1 step=130 loss=0.5714
# epoch=1 step=140 loss=0.6177
# epoch=1 step=150 loss=0.6627
# epoch=1 step=160 loss=0.5534
# epoch=1 step=170 loss=0.5666
# epoch=1 step=180 loss=0.6631
# epoch=1 step=190 loss=0.4956
# epoch=1 step=200 loss=0.5803
# epoch=1 step=210 loss=0.5239
# epoch=1 step=220 loss=0.6107
# epoch=1 step=230 loss=0.4798
# epoch=1 step=240 loss=0.5209
# epoch=1 step=250 loss=0.4224
# epoch=1 step=260 loss=0.6782
# epoch=1 step=270 loss=0.5788
# epoch=1 step=280 loss=0.5690
# epoch=1 step=290 loss=0.4005
# epoch=1 step=300 loss=0.5129
# epoch=1 step=310 loss=0.7800
# epoch=1 step=320 loss=0.5246
# epoch=1 step=330 loss=0.5387
# epoch=1 step=340 loss=0.6152
# epoch=1 step=350 loss=0.4775
# epoch=1 step=360 loss=0.4949
# epoch=1 step=370 loss=0.5503
# epoch=1 step=380 loss=0.5920
# epoch=1 step=390 loss=0.3552
# epoch=1 step=400 loss=0.5979
# epoch=1 step=410 loss=0.5842
# epoch=1 step=420 loss=0.5721
# epoch=1 step=430 loss=0.4579
# epoch=1 step=440 loss=0.4136
# epoch=1 step=450 loss=0.4867
# epoch=1 step=2020 loss=0.3280
# epoch=1 step=2030 loss=0.4018
# epoch=1 step=2040 loss=0.3430
# epoch=1 step=2050 loss=0.2535
# epoch=1 step=2060 loss=0.3915
# epoch=1 step=2070 loss=0.3305
# epoch=1 step=2080 loss=0.2836
# epoch=1 step=2090 loss=0.3453
# epoch=1 step=2100 loss=0.4337
# epoch=1 step=2110 loss=0.4060
# epoch=1 step=2120 loss=0.4151
# epoch=1 step=2130 loss=0.3863
# epoch=1 step=2140 loss=0.4753
# epoch=1 step=2150 loss=0.2944
# epoch=1 step=2160 loss=0.3419
# epoch=1 step=2170 loss=0.5517
# epoch=1 step=2180 loss=0.3189
# epoch=1 step=2190 loss=0.4919
# epoch=1 step=2200 loss=0.3584
# epoch=1 step=2210 loss=0.4111
# epoch=1 step=2220 loss=0.3506
# epoch=1 step=2230 loss=0.3453
# epoch=1 step=2240 loss=0.3206
# epoch=1 step=2250 loss=0.3617
# epoch=1 step=2260 loss=0.3368
# epoch=1 step=2270 loss=0.2665
# epoch=1 step=2280 loss=0.4723
# epoch=1 step=2290 loss=0.3808
# epoch=1 step=2300 loss=0.3833
# epoch=1 step=2310 loss=0.2766
# epoch=1 step=2320 loss=0.3758
# epoch=1 step=2330 loss=0.4478
# epoch=1 step=2340 loss=0.4098
# epoch=1 step=2350 loss=0.4752
# epoch=1 step=2360 loss=0.3534
# epoch=1 step=2370 loss=0.5629
# epoch=1 step=2380 loss=0.4560
# epoch=1 step=2390 loss=0.4660
# epoch=1 step=2400 loss=0.3751
# epoch=1 step=2410 loss=0.3059
# val: evaluating 1048 items in 66 batches
# val: batch 1/66 items 16/1048 elapsed 151.2s
# val: batch 10/66 items 160/1048 elapsed 1131.6s
# val: batch 20/66 items 320/1048 elapsed 2052.0s
# val: batch 30/66 items 480/1048 elapsed 3097.5s
# val: batch 40/66 items 640/1048 elapsed 4043.6s
# val: batch 50/66 items 800/1048 elapsed 4962.5s
# val: batch 60/66 items 960/1048 elapsed 6098.6s
# val: batch 66/66 items 1048/1048 elapsed 6645.7s
# {
#   "adapter_enabled": true,
#   "eval_artifact_dir": null,
#   "experiment_id": "c03_balanced_answer",
#   "matched_lora_modules": [
#     "model.text_model.layers.0.self_attn.k_proj",
#     "model.text_model.layers.0.self_attn.o_proj",
#     "model.text_model.layers.0.self_attn.q_proj",
#     "model.text_model.layers.0.self_attn.v_proj",
#     "model.text_model.layers.1.self_attn.k_proj",
#     "model.text_model.layers.1.self_attn.o_proj",
#     "model.text_model.layers.1.self_attn.q_proj",
#     "model.text_model.layers.1.self_attn.v_proj",
#     "model.text_model.layers.10.self_attn.k_proj",
#     "model.text_model.layers.10.self_attn.o_proj",
#     "model.text_model.layers.10.self_attn.q_proj",
#     "model.text_model.layers.10.self_attn.v_proj",
#     "model.text_model.layers.11.self_attn.k_proj",
#     "model.text_model.layers.11.self_attn.o_proj",
#     "model.text_model.layers.11.self_attn.q_proj",
#     "model.text_model.layers.11.self_attn.v_proj",
#     "model.text_model.layers.12.self_attn.k_proj",
#     "model.text_model.layers.26.self_attn.q_proj",
#     "model.text_model.layers.26.self_attn.v_proj",
#     "model.text_model.layers.27.self_attn.k_proj",
#     "model.text_model.layers.27.self_attn.o_proj",
#     "model.text_model.layers.27.self_attn.q_proj",
#     "model.text_model.layers.27.self_attn.v_proj",
#     "model.text_model.layers.28.self_attn.k_proj",
#     "model.text_model.layers.28.self_attn.o_proj",
#     "model.text_model.layers.28.self_attn.q_proj",
#     "model.text_model.layers.28.self_attn.v_proj",
#     "model.text_model.layers.29.self_attn.k_proj",
#     "model.text_model.layers.29.self_attn.o_proj",
#     "model.text_model.layers.29.self_attn.q_proj",
#     "model.text_model.layers.29.self_attn.v_proj",
#     "model.text_model.layers.3.self_attn.k_proj",
#     "model.text_model.layers.3.self_attn.o_proj",
#     "model.text_model.layers.3.self_attn.q_proj",
#     "model.text_model.layers.3.self_attn.v_proj",
#     "model.text_model.layers.30.self_attn.k_proj",
#     "model.text_model.layers.30.self_attn.o_proj",
#     "model.text_model.layers.30.self_attn.q_proj",
#     "model.text_model.layers.30.self_attn.v_proj",
#     "model.text_model.layers.31.self_attn.k_proj",
#     "model.text_model.layers.31.self_attn.o_proj",
#     "model.text_model.layers.31.self_attn.q_proj",
#     "model.text_model.layers.31.self_attn.v_proj",
#     "model.text_model.layers.4.self_attn.k_proj",
#     "model.text_model.layers.4.self_attn.o_proj",
#     "model.text_model.layers.4.self_attn.q_proj",
#     "model.text_model.layers.4.self_attn.v_proj",
#     "model.text_model.layers.5.self_attn.k_proj",
#     "model.text_model.layers.5.self_attn.o_proj",
#     "model.text_model.layers.5.self_attn.q_proj",
#     "model.text_model.layers.5.self_attn.v_proj",
#     "model.text_model.layers.6.self_attn.k_proj",
#     "model.text_model.layers.6.self_attn.o_proj",
#     "model.text_model.layers.6.self_attn.q_proj",
#     "model.text_model.layers.6.self_attn.v_proj",
#     "model.text_model.layers.7.self_attn.k_proj",
#     "model.text_model.layers.7.self_attn.o_proj",
#     "model.text_model.layers.7.self_attn.q_proj",
#     "model.text_model.layers.7.self_attn.v_proj",
#     "model.text_model.layers.8.self_attn.k_proj",
#     "model.text_model.layers.8.self_attn.o_proj",
#     "model.text_model.layers.8.self_attn.q_proj",
#     "model.text_model.layers.8.self_attn.v_proj",
#     "model.text_model.layers.9.self_attn.k_proj",
#     "model.text_model.layers.9.self_attn.o_proj",
#     "model.text_model.layers.9.self_attn.q_proj",
#     "model.text_model.layers.9.self_attn.v_proj",
#     "model.vision_model.encoder.layers.0.self_attn.k_proj",
#     "model.vision_model.encoder.layers.0.self_attn.out_proj",
#     "model.vision_model.encoder.layers.0.self_attn.q_proj",
#     "model.vision_model.encoder.layers.0.self_attn.v_proj",
#     "model.vision_model.encoder.layers.1.self_attn.k_proj",
#     "model.vision_model.encoder.layers.1.self_attn.out_proj",
#     "model.vision_model.encoder.layers.1.self_attn.q_proj",
#     "model.vision_model.encoder.layers.1.self_attn.v_proj",
#     "model.vision_model.encoder.layers.10.self_attn.k_proj",
#     "model.vision_model.encoder.layers.10.self_attn.out_proj",
#     "model.vision_model.encoder.layers.10.self_attn.q_proj",
#     "model.vision_model.encoder.layers.10.self_attn.v_proj",
#     "model.vision_model.encoder.layers.11.self_attn.k_proj",
#     "model.vision_model.encoder.layers.11.self_attn.out_proj",
#     "model.vision_model.encoder.layers.11.self_attn.q_proj",
#     "model.vision_model.encoder.layers.11.self_attn.v_proj",
#     "model.vision_model.encoder.layers.2.self_attn.k_proj",
#     "model.vision_model.encoder.layers.2.self_attn.out_proj",
#     "model.vision_model.encoder.layers.2.self_attn.q_proj",
#     "model.vision_model.encoder.layers.2.self_attn.v_proj",
#     "model.vision_model.encoder.layers.3.self_attn.k_proj",
#     "model.vision_model.encoder.layers.3.self_attn.out_proj",
#     "model.vision_model.encoder.layers.3.self_attn.q_proj",
#     "model.vision_model.encoder.layers.3.self_attn.v_proj",
#     "model.vision_model.encoder.layers.4.self_attn.k_proj",
#     "model.vision_model.encoder.layers.4.self_attn.out_proj",
#     "model.vision_model.encoder.layers.4.self_attn.q_proj",
#     "model.vision_model.encoder.layers.4.self_attn.v_proj",
#     "model.vision_model.encoder.layers.5.self_attn.k_proj",
#     "model.vision_model.encoder.layers.5.self_attn.out_proj",
#     "model.vision_model.encoder.layers.5.self_attn.q_proj",
#     "model.vision_model.encoder.layers.5.self_attn.v_proj",
#     "model.vision_model.encoder.layers.6.self_attn.k_proj",
#     "model.vision_model.encoder.layers.6.self_attn.out_proj",
#     "model.vision_model.encoder.layers.6.self_attn.q_proj",
#     "model.vision_model.encoder.layers.6.self_attn.v_proj",
#     "model.vision_model.encoder.layers.7.self_attn.k_proj",
#     "model.vision_model.encoder.layers.7.self_attn.out_proj",
#     "model.vision_model.encoder.layers.7.self_attn.q_proj",
#     "model.vision_model.encoder.layers.7.self_attn.v_proj",
#     "model.vision_model.encoder.layers.8.self_attn.k_proj",
#     "model.vision_model.encoder.layers.8.self_attn.out_proj",
#     "model.vision_model.encoder.layers.8.self_attn.q_proj",
#     "model.vision_model.encoder.layers.8.self_attn.v_proj",
#     "model.vision_model.encoder.layers.9.self_attn.k_proj",
#     "model.vision_model.encoder.layers.9.self_attn.out_proj",
#     "model.vision_model.encoder.layers.9.self_attn.q_proj",
#     "model.vision_model.encoder.layers.9.self_attn.v_proj"
#   ],
#   "output_dir": "/content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100/full/c03_balanced_answer_seed42",
#   "resolved_config_path": "/content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100/full/c03_balanced_answer_seed42/resolved_config.yaml",
#   "run_mode": "train_eval",
#   "run_name": "c03_balanced_answer_seed42",
#   "run_summary_path": "/content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100/full/c03_balanced_answer_seed42/run_summary.yaml",
#   "submission_path": null,
#   "target_lora_modules": [
#     "q_proj",
#     "k_proj",
#     "v_proj",
#     "o_proj",
#     "out_proj"
#   ],
#   "test_predictions_path": null,
#   "trainable_parameters": 4456448,
#   "unmatched_lora_targets": [],
#   "val_metrics": {
#     "accuracy_by_num_choices": {
#       "2": 0.7377049180327869,
#       "3": 0.6279527559055118,
#       "4": 0.8293650793650794,
#       "5": 0.45454545454545453
#     },
#     "accuracy_by_subject": {
#       "language science": 0.32142857142857145,
#       "natural science": 0.6563706563706564,
#       "social science": 0.8600823045267489
#     },
#     "accuracy_by_task": {
#       "closed choice": 0.6975369458128079,
#       "true-or false": 0.6060606060606061
#     },
#     "overall_accuracy": 0.6946564885496184,
#     "prediction_distribution": {
#       "0": 0.34541984732824427,
#       "1": 0.3416030534351145,
#       "2": 0.23091603053435114,
#       "3": 0.07919847328244274,
#       "4": 0.0028625954198473282
#     },
#     "two_choice_accuracy": 0.7377049180327869,
#     "two_choice_support": 244,
#     "yes_no_true_false_accuracy": 0.6060606060606061,
#     "yes_no_true_false_support": 33
#   },
#   "val_predictions_path": "/content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100/full/c03_balanced_answer_seed42/artifacts/val_predictions.jsonl"
# }
# 2026-04-27 02:53:06.647278: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-27 02:53:06.666316: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777258386.689926   13132 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777258386.697437   13132 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777258386.716806   13132 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777258386.716839   13132 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777258386.716841   13132 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777258386.716843   13132 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-27 02:53:06.721825: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# `torch_dtype` is deprecated! Use `dtype` instead!
# /content/dl-kaggle-competition-final/src/training/train.py:211: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=torch.cuda.is_available() and config.training.fp16)
# /usr/local/lib/python3.12/dist-packages/torch/utils/checkpoint.py:232: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   check_backward_validity(args)
# Resolved config: /content/drive/MyDrive/p2p_runs/stage3_balanced_answer_index_a100/full/c03_balanced_answer_seed42/resolved_config.yaml
# experiment_id: c03_balanced_answer
# parent_experiment_id: f04_candidate_yes_no
# formulation.mode: candidate_yes_no
# prompting.template: candidate_yes_no
# sampling.mode: balanced_answer_index
# training.epochs: 1
# training.bf16: True
# training.fp16: False
# training.eval_batch_size: 16
# scoring.max_completion_batch_size: 16
# fields: ['image', 'question']

# %% [markdown]
# ## 7. Optional Final Train+Val Test Prediction
#
# Run only after this ablation wins validation selection. This trains on train+val via `--final-retrain` and predicts the unlabeled test split; it does not train on test labels.

# %%
RUN_FINAL_RETRAIN = False

if RUN_FINAL_RETRAIN:
    final_root = Path(DRIVE_OUTPUT_DIR) / "final_train_val_test"
    final_args = [
        "scripts/run_experiment.py",
        "--experiment", EXPERIMENT_ID,
        "--output-dir", str(final_root),
        "--final-retrain",
        "--predict-test",
    ]
    extend_with_overrides(final_args, with_common_overrides([
        "training.epochs=1",
        "training.bf16=true",
        "training.fp16=false",
        f"training.eval_batch_size={EVAL_BATCH_SIZE}",
        f"scoring.max_completion_batch_size={INFERENCE_COMPLETION_BATCH_SIZE}",
    ]))
    run_repo_command(final_args)
    verify_resolved_config(final_root)
else:
    print("Set RUN_FINAL_RETRAIN = True only after this ablation wins validation selection.")

# %% [markdown]
# ## 8. Summarize Results
#
# Print the top validation runs from `results/experiments.csv`.

# %%
summary_args = [
    "scripts/summarize_results.py",
    "--sort-by", "val_accuracy",
    "--top", "20",
]
run_repo_command(summary_args)
